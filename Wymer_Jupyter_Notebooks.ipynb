# %%
#Web Scrapping with Jupyter

#Import tools needed
import urllib3
import certifi
import re
import pandas as pd


http = urllib3.PoolManager(ca_certs=certifi.where())

#Establish website and formats
url = "https://www.metacritic.com/browse/movies/score/metascore/year/filtered?year_selected=2006&sort=desc&view=detailed"
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0"
response = http.request('GET', url, headers={"User-Agent": user_agent})
page_content = response.data.decode('utf-8')


#Build out regex setups
titles = r'class="title"><h3>(.*)<\/h3><\/a>'
release_dates = r'<span>(?P<ReleaseDate>.*\d)<\/span>'
summaries = r'<div class="summary">\s(.*)[\s\S]*?<\/div>'
meta_scores = r'<div class="metascore_w large movie positive">(.*)<\/div>\s*<\/a>\s*<\/div>\s*<div class="clamp-userscore">'
thumbnails = re.compile(r'"><img src="([h].*)" alt="', flags=re.M)

#Build out searches
m_titles = re.findall(titles, page_content)
m_release_dates = re.findall(release_dates, page_content)
m_summaries = re.findall(summaries, page_content)
m_meta_scores = re.findall(meta_scores, page_content)
m_thumbnails = thumbnails.findall(page_content)

#Checking lengths of each search run to make sure the searches functioned properly
#print(len(m_titles))
#print(len(m_release_dates))
#print(len(m_summaries))
#print(len(m_meta_scores))
#print(len(m_thumbnails))

#Build Pandas Dataframe to store outputs
movies = pd.DataFrame({
    'Title': m_titles,
    'Release Date': m_release_dates,
    'Summary': m_summaries,
    'Score': m_meta_scores,
    'Thumbnail': m_thumbnails
})

with pd.option_context('display.max_rows', None,
                       'display.max_columns', None                       
                       ):
    display(movies)
# Out:
#                                                 Title        Release Date
# 0                                     Pan's Labyrinth   December 29, 2006  \
# 1                                           The Queen  September 30, 2006
# 2                                           United 93      April 28, 2006
# 3                                 The Lives of Others    December 1, 2006
# 4       When the Levees Broke: A Requiem in Four Acts     August 21, 2006
# 5   Borat: Cultural Learnings of America for Make ...    November 3, 2006
# 6                               Letters from Iwo Jima   December 20, 2006
# 7                        The Fallen Idol (re-release)   February 10, 2006
# 8                                L'Enfant (The Child)      March 24, 2006
# 9                          The Death of Mr. Lazarescu      April 26, 2006
# 10                                           Fateless     January 6, 2006
# 11                               Deliver Us from Evil    October 13, 2006
# 12                                    Our Daily Bread   November 24, 2006
# 13                    Andy Warhol: A Documentary Film   September 1, 2006
# 14                                       The Departed     October 6, 2006
# 15                                        Half Nelson     August 11, 2006
# 16                                       Street Fight   February 22, 2006
# 17                          Neil Young: Heart of Gold   February 10, 2006
# 18                                    Children of Men   December 25, 2006
# 19                                              49 Up     October 6, 2006
# 20                                            Old Joy  September 20, 2006
# 21                                             Volver    November 3, 2006
# 22                                             Lassie   September 1, 2006
# 23                       Dave Chappelle's Block Party       March 3, 2006
# 24                                  Iraq in Fragments   November 10, 2006
# 25                                Mutual Appreciation   September 1, 2006
# 26                                              Venus   December 21, 2006
# 27                                        Three Times      April 26, 2006
# 28                                      Days of Glory    December 6, 2006
# 29                                            Requiem    October 20, 2006
# 30                                      Black Orpheus   February 24, 2006
# 31                                  The Devil's Miner      March 17, 2006
# 32                                      Casino Royale   November 17, 2006
# 33             Tristram Shandy: A Cock and Bull Story    January 27, 2006
# 34                               Little Miss Sunshine       July 26, 2006
# 35    Jonestown: The Life and Death of Peoples Temple    October 20, 2006
# 36                                          Gabrielle       July 14, 2006
# 37                               Flags of Our Fathers    October 20, 2006
# 38                                    So Much So Fast    October 11, 2006
# 39                                      Chats perchés   December 20, 2006
# 40                                           Deep Sea       March 3, 2006
# 41                       The Real Dirt on Farmer John    January 20, 2006
# 42                                           The Aura   November 17, 2006
# 43                  Pusher II: With Blood On My Hands     August 18, 2006
# 44                                         Happy Feet   November 17, 2006
# 45                                    51 Birch Street    October 18, 2006
# 46                                     Shut Up & Sing    October 27, 2006
# 47                      The Devil and Daniel Johnston      March 31, 2006
# 48                                    Mountain Patrol      April 14, 2006
# 49                                      The War Tapes        June 2, 2006
# 50                                        Little Fish   February 24, 2006
# 51                                              Water      April 28, 2006
# 52                                         Inside Man      March 24, 2006
# 53                                         Dreamgirls   December 15, 2006
# 54                                   The Ritchie Boys    October 13, 2006
# 55                                   The Hidden Blade       June 23, 2006
# 56                      Sophie Scholl: The Final Days   February 17, 2006
# 57                                         Sweet Land    October 18, 2006
# 58                              An Inconvenient Truth        May 24, 2006
# 59                                     Lady Vengeance      April 28, 2006
# 60                                    Little Children     October 6, 2006
# 61                           A Prairie Home Companion        June 9, 2006
# 62                         This Film Is Not Yet Rated   September 1, 2006
# 63                                     The Bridesmaid      August 4, 2006
# 64                                   The Ground Truth  September 15, 2006
# 65                                        Iron Island      March 31, 2006
# 66                            Shakespeare Behind Bars      March 10, 2006
# 67                                       Flushed Away    November 3, 2006
# 68                                        Duck Season      March 10, 2006
# 69                          The Last King of Scotland  September 27, 2006
# 70                                       Take My Eyes      March 17, 2006
# 71                                            Commune    November 3, 2006
# 72                              The Heart of the Game        June 9, 2006
# 73                                   The History Boys   November 21, 2006
# 74                                       Sir! No Sir!       April 7, 2006
# 75                             My Country, My Country      August 4, 2006
# 76                                      State of Fear    January 11, 2006
# 77                                   A Scanner Darkly        July 7, 2006
# 78                                           Wordplay       June 16, 2006
# 79                                    The Proposition         May 5, 2006
# 80                                         Somersault      April 21, 2006
# 81         Crossing the Bridge: The Sound of Istanbul        June 9, 2006
# 82                                      Inland Empire    December 6, 2006
# 83                         The Cave of the Yellow Dog   November 10, 2006
# 84                                      Heading South        July 7, 2006
# 85                                               Cars        June 9, 2006
# 86                                    The Puffy Chair        June 2, 2006
# 87                      Metal: A Headbanger's Journey      April 14, 2006
# 88                Riding Alone for Thousands of Miles   September 1, 2006
# 89                                 Notes on a Scandal   December 27, 2006
# 90                               The Fall of Fujimori    January 18, 2006
# 91                                           Climates    October 27, 2006
# 92                                        Quinceañera      August 4, 2006
# 93                                   Superman Returns       June 28, 2006
# 94                          Tibet: A Buddhist Trilogy      March 31, 2006
# 95                                                  4       April 7, 2006
# 96                                        Bubot Niyar   September 1, 2006
# 97                                Akeelah and the Bee      April 28, 2006
# 98                                              Brick      March 31, 2006
# 99                 Pusher III: I'm the Angel of Death     August 18, 2006
#
#                                               Summary Score
# 0                           Following a bloody civ...    98  \
# 1                           The Queen takes audien...    91
# 2                           Acclaimed filmmaker Pa...    90
# 3                           At once a political th...    89
# 4                           An examination of the ...    89
# 5                           The movie film is a go...    89
# 6                           In this companion piec...    89
# 7                           Adapted from Graham Gr...    88
# 8                           Dispossessed twenty-ye...    87
# 9                           Anyone who has waited ...    87
# 10                          Fateless is based on t...    87
# 11                          This controversial doc...    86
# 12                          This documentary aims ...    86
# 13                          Ric Burns's 4-hour, ep...    86
# 14                          This gritty crime dram...    85
# 15                          Dan, an idealistic inn...    85
# 16                          This documentary chron...    85
# 17                          Neil Young: Heart of G...    85
# 18                          Children of Men envisa...    84
# 19                          49 UP is the seventh f...    84
# 20                          Old Joy is the story o...    84
# 21                          Three generations of w...    84
# 22                          The film is set on the...    84
# 23                          A genuine crowd-please...    84
# 24                          Iraq in Fragments illu...    84
# 25                          Alan (Rice), a musicia...    84
# 26                          An aging English actor...    82
# 27                          Hou Hsiao-hsien delive...    82
# 28                          1943.  The young North...    82
# 29                          Inspired by the same e...    82
# 30                          1960 Academy Award Win...    81
# 31                          The Devil's Miner is t...    81
# 32                          After earning his lice...    80
# 33                          A zesty celebration of...    80
# 34                          Little Miss Sunshine i...    80
# 35                          This documentary tells...    79
# 36                          Patrice Chéreau direct...    79
# 37                          Based on the bestselli...    79
# 38                          A black-humored cliffh...    79
# 39                          In his newest film, Fr...    79
# 40                          Deep Sea 3D, the new i...    78
# 41                          The epic tale of a mav...    78
# 42                          On his first ever hunt...    78
# 43                          Pusher II tells the st...    78
# 44                          A tone-deaf, tap danci...    77
# 45                          Both unexpectedly funn...    77
# 46                          At a time when the Uni...    77
# 47                          The Devil and Daniel J...    77
# 48                          Mountain Patrol: Kekex...    77
# 49                          In March 2004, just as...    77
# 50                          How do you learn to lo...    77
# 51                          Set in 1938 Colonial I...    77
# 52                          The perfect bank robbe...    76
# 53                          Twenty-five years afte...    76
# 54                          Christian Bauer's film...    76
# 55                          Munezo Katagiri (Nagas...    76
# 56                          The true story of Germ...    76
# 57                          Set in Southern Minnes...    75
# 58                          This documentary offer...    75
# 59                          Lady Vengeance is the ...    75
# 60                          Based on the novel by ...    75
# 61                          Director Robert Altman...    75
# 62                          Academy Award-nominate...    75
# 63                          It's love at first sig...    74
# 64                          Patricia Foulkrod's do...    74
# 65                          The story of a communi...    74
# 66                          Shakespeare Behind Bar...    74
# 67                          From the teams behind ...    74
# 68                          An unlikely foursome s...    74
# 69                          In an incredible twist...    74
# 70                          Take My Eyes tackles t...    74
# 71                          With its spotlight on ...    74
# 72                          This documentary focus...    74
# 73                          The History Boys tells...    74
# 74                          This documentary exami...    74
# 75                          Working alone in Iraq ...    74
# 76                          In this documentary, t...    74
# 77                          Based on legendary sci...    73
# 78                          Wordplay focuses on th...    73
# 79                          Set against the harsh ...    73
# 80                          An erotic, lyrical dep...    73
# 81                          A European musician an...    73
# 82                          The latest hallucinato...    73
# 83                          A Mongolian nomad fami...    73
# 84                          On the sun drenched is...    73
# 85                          This is a fast-paced c...    73
# 86                          The story of three ver...    73
# 87                          Sam Dunn is a 30-year ...    73
# 88                          From three-time Academ...    73
# 89                          Based on the novel by ...    73
# 90                          The Fall of Fujimori i...    73
# 91                          A gorgeous rumination ...    72
# 92                          Quinceañera is a look ...    72
# 93                          Five years after his m...    72
# 94                          Originally presented d...    72
# 95                          Three strangers meet i...    72
# 96                          After closing the bord...    72
# 97                          An inspirational drama...    72
# 98                          Brick, while taking it...    72
# 99                          PUSHER III takes place...    72
#
#                                             Thumbnail
# 0   https://static.metacritic.com/images/products/...
# 1   https://static.metacritic.com/images/products/...
# 2   https://static.metacritic.com/images/products/...
# 3   https://static.metacritic.com/images/products/...
# 4   https://static.metacritic.com/images/products/...
# 5   https://static.metacritic.com/images/products/...
# 6   https://static.metacritic.com/images/products/...
# 7   https://static.metacritic.com/images/products/...
# 8   https://static.metacritic.com/images/products/...
# 9   https://static.metacritic.com/images/products/...
# 10  https://static.metacritic.com/images/products/...
# 11  https://static.metacritic.com/images/products/...
# 12  https://static.metacritic.com/images/products/...
# 13  https://static.metacritic.com/images/products/...
# 14  https://static.metacritic.com/images/products/...
# 15  https://static.metacritic.com/images/products/...
# 16  https://static.metacritic.com/images/products/...
# 17  https://static.metacritic.com/images/products/...
# 18  https://static.metacritic.com/images/products/...
# 19  https://static.metacritic.com/images/products/...
# 20  https://static.metacritic.com/images/products/...
# 21  https://static.metacritic.com/images/products/...
# 22  https://static.metacritic.com/images/products/...
# 23  https://static.metacritic.com/images/products/...
# 24  https://static.metacritic.com/images/products/...
# 25  https://static.metacritic.com/images/products/...
# 26  https://static.metacritic.com/images/products/...
# 27  https://static.metacritic.com/images/products/...
# 28  https://static.metacritic.com/images/products/...
# 29  https://static.metacritic.com/images/products/...
# 30  https://static.metacritic.com/images/products/...
# 31  https://static.metacritic.com/images/products/...
# 32  https://static.metacritic.com/images/products/...
# 33  https://static.metacritic.com/images/products/...
# 34  https://static.metacritic.com/images/products/...
# 35  https://static.metacritic.com/images/products/...
# 36  https://static.metacritic.com/images/products/...
# 37  https://static.metacritic.com/images/products/...
# 38  https://static.metacritic.com/images/products/...
# 39  https://static.metacritic.com/images/products/...
# 40  https://static.metacritic.com/images/products/...
# 41  https://static.metacritic.com/images/products/...
# 42  https://static.metacritic.com/images/products/...
# 43  https://static.metacritic.com/images/products/...
# 44  https://static.metacritic.com/images/products/...
# 45  https://static.metacritic.com/images/products/...
# 46  https://static.metacritic.com/images/products/...
# 47  https://static.metacritic.com/images/products/...
# 48  https://static.metacritic.com/images/products/...
# 49  https://static.metacritic.com/images/products/...
# 50  https://static.metacritic.com/images/products/...
# 51  https://static.metacritic.com/images/products/...
# 52  https://static.metacritic.com/images/products/...
# 53  https://static.metacritic.com/images/products/...
# 54  https://static.metacritic.com/images/products/...
# 55  https://static.metacritic.com/images/products/...
# 56  https://static.metacritic.com/images/products/...
# 57  https://static.metacritic.com/images/products/...
# 58  https://static.metacritic.com/images/products/...
# 59  https://static.metacritic.com/images/products/...
# 60  https://static.metacritic.com/images/products/...
# 61  https://static.metacritic.com/images/products/...
# 62  https://static.metacritic.com/images/products/...
# 63  https://static.metacritic.com/images/products/...
# 64  https://static.metacritic.com/images/products/...
# 65  https://static.metacritic.com/images/products/...
# 66  https://static.metacritic.com/images/products/...
# 67  https://static.metacritic.com/images/products/...
# 68  https://static.metacritic.com/images/products/...
# 69  https://static.metacritic.com/images/products/...
# 70  https://static.metacritic.com/images/products/...
# 71  https://static.metacritic.com/images/products/...
# 72  https://static.metacritic.com/images/products/...
# 73  https://static.metacritic.com/images/products/...
# 74  https://static.metacritic.com/images/products/...
# 75  https://static.metacritic.com/images/products/...
# 76  https://static.metacritic.com/images/products/...
# 77  https://static.metacritic.com/images/products/...
# 78  https://static.metacritic.com/images/products/...
# 79  https://static.metacritic.com/images/products/...
# 80  https://static.metacritic.com/images/products/...
# 81  https://static.metacritic.com/images/products/...
# 82  https://static.metacritic.com/images/products/...
# 83  https://static.metacritic.com/images/products/...
# 84  https://static.metacritic.com/images/products/...
# 85  https://static.metacritic.com/images/products/...
# 86  https://static.metacritic.com/images/products/...
# 87  https://static.metacritic.com/images/products/...
# 88  https://static.metacritic.com/images/products/...
# 89  https://static.metacritic.com/images/products/...
# 90  https://static.metacritic.com/images/products/...
# 91  https://static.metacritic.com/images/products/...
# 92  https://static.metacritic.com/images/products/...
# 93  https://static.metacritic.com/images/products/...
# 94  https://static.metacritic.com/images/products/...
# 95  https://static.metacritic.com/images/products/...
# 96  https://static.metacritic.com/images/products/...
# 97  https://static.metacritic.com/images/products/...
# 98  https://static.metacritic.com/images/products/...
# 99  https://static.metacritic.com/images/products/...
